# %% [markdown]
# # Example 2 — Census County Business Patterns State Context
#
# This notebook loads the official 2023 CBP state download from the U.S. Census Bureau.

# %%
from capital_access_atlas import load_cbp_state_file, summarize_cbp_state_totals

# %%
raw_cbp = load_cbp_state_file()
raw_cbp.head()

# %%
state_totals = summarize_cbp_state_totals(raw_cbp)
state_totals.head(10)

# %%
state_totals[[
    'state_name',
    'establishments',
    'employment',
    'annual_payroll_thousands',
]].sort_values('establishments', ascending=False).head(15)

# %% [markdown]
# CBP covers establishments with paid employees and includes disclosure protections. Consult the official Census documentation for definitions and limitations.
